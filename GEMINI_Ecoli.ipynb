# %%
import torch
import pandas as pd
from torch_geometric.data import Data
from sklearn.model_selection import train_test_split
import torch.nn.functional as F

# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')  # Automatically choose CPU or GPU

# Load gene expression matrix (genes as columns, samples as rows)
# Assuming the E. coli expression data file is named 'DREAM5_ecoli_data.tsv'
expression_df = pd.read_csv("DREAM5_ecoli_data.tsv", sep="\t", header=0)
gene_ids = expression_df.columns.tolist()  # Get gene IDs from column names

# Convert expression matrix to node features tensor
node_features = torch.tensor(expression_df.values.T, dtype=torch.float).to(device)
print(f"Node features shape: {node_features.shape}")  # Check shape

# Load mutual information data (edges) with columns: 'Gene1', 'Gene2', 'MI'
# Assuming MI data for E. coli is in 'DREAM5_MI_ecoli_3col.csv'
mi_df = pd.read_csv("MI_ecoli_3col.csv")
mi_threshold = 0  # Set an MI threshold to filter strong interactions
mi_df = mi_df[mi_df['Mutual_Information'] > mi_threshold]

# Convert gene names to indices based on gene_ids list for compatibility with PyTorch Geometric
gene_to_idx = {gene: idx for idx, gene in enumerate(gene_ids)}

# Filter only valid gene pairs based on gene expression matrix columns
mi_df = mi_df[mi_df['Gene1'].isin(gene_to_idx) & mi_df['Gene2'].isin(gene_to_idx)]
mi_df['Gene1_idx'] = mi_df['Gene1'].map(gene_to_idx)
mi_df['Gene2_idx'] = mi_df['Gene2'].map(gene_to_idx)

# Convert to edge index tensor and edge weight tensor
edge_index = torch.tensor(mi_df[['Gene1_idx', 'Gene2_idx']].values.T, dtype=torch.long).to(device)
edge_weight = torch.tensor(mi_df['Mutual_Information'].values, dtype=torch.float).to(device)
print(f"Edge index shape: {edge_index.shape}")  # Check shape

# Load the ground truth interaction matrix (square matrix of 1s and 0s)
# Assuming interaction data for E. coli is in 'interaction_ecoli.csv'
interaction_matrix = pd.read_csv("interaction_ecoli.csv", header=0).values  # Convert to numpy array

# Function to replace any string labels with 0
def handle_non_binary_labels(labels):
    for idx, label in enumerate(labels):
        if isinstance(label, str):  # Check if the label is a string
            print(f"Replacing string label at index {idx}: {label}")  # Print the problematic label
            labels[idx] = 0  # Replace string label with 0
    return labels

# Split edges and weights into train, validation, and test sets, each being 5% of total
num_edges = edge_index.shape[1]
split_size = int(0.05 * num_edges)  # 5% of total edges

# Randomly shuffle and select indices for train, val, and test sets
edge_indices = list(range(num_edges))
train_indices, temp_indices = train_test_split(edge_indices, train_size=split_size, random_state=42)
val_indices, test_indices = train_test_split(temp_indices, train_size=split_size, random_state=42)

# Subset edge_index and edge_weight for each split
edge_index_train = edge_index[:, train_indices]
edge_weight_train = edge_weight[train_indices]
edge_index_val = edge_index[:, val_indices]
edge_weight_val = edge_weight[val_indices]
edge_index_test = edge_index[:, test_indices]
edge_weight_test = edge_weight[test_indices]

# Sanity check for edge splits
print(f"Training edge indices: {edge_index_train.shape}")
print(f"Validation edge indices: {edge_index_val.shape}")
print(f"Test edge indices: {edge_index_test.shape}")

# Match ground truth labels for the corresponding splits
train_labels = []
val_labels = []
test_labels = []

# Split ground truth for each edge subset
for edge in edge_index_train.T:
    i, j = edge.cpu().numpy()
    train_labels.append(interaction_matrix[i, j])  # Append the corresponding label

for edge in edge_index_val.T:
    i, j = edge.cpu().numpy()
    val_labels.append(interaction_matrix[i, j])  # Append the corresponding label

for edge in edge_index_test.T:
    i, j = edge.cpu().numpy()
    test_labels.append(interaction_matrix[i, j])  # Append the corresponding label

# Handle non-binary labels if needed
train_labels = handle_non_binary_labels(train_labels)
val_labels = handle_non_binary_labels(val_labels)
test_labels = handle_non_binary_labels(test_labels)

# Convert lists to tensors
train_labels = torch.tensor(train_labels, dtype=torch.float).to(device)
val_labels = torch.tensor(val_labels, dtype=torch.float).to(device)
test_labels = torch.tensor(test_labels, dtype=torch.float).to(device)

# Prepare PyTorch Geometric Data objects
train_data = Data(x=node_features, edge_index=edge_index_train, edge_attr=edge_weight_train, y=train_labels)
val_data = Data(x=node_features, edge_index=edge_index_val, edge_attr=edge_weight_val, y=val_labels)
test_data = Data(x=node_features, edge_index=edge_index_test, edge_attr=edge_weight_test, y=test_labels)

# Verify that the data is ready for training
print(f"Training data: {train_data}")
print(f"Validation data: {val_data}")
print(f"Test data: {test_data}")

# Print the shape for each dataset to verify correctness
print(f"Training node features shape: {train_data.x.shape}")
print(f"Training edge index shape: {train_data.edge_index.shape}")
print(f"Training edge weight shape: {train_data.edge_attr.shape}")
print(f"Training labels shape: {train_data.y.shape}")

print(f"Validation node features shape: {val_data.x.shape}")
print(f"Validation edge index shape: {val_data.edge_index.shape}")
print(f"Validation edge weight shape: {val_data.edge_attr.shape}")
print(f"Validation labels shape: {val_data.y.shape}")

print(f"Test node features shape: {test_data.x.shape}")
print(f"Test edge index shape: {test_data.edge_index.shape}")
print(f"Test edge weight shape: {test_data.edge_attr.shape}")
print(f"Test labels shape: {test_data.y.shape}")
# Out:
# Node features shape: torch.Size([4511, 805])
# Edge index shape: torch.Size([2, 19388736])
# Training edge indices: torch.Size([2, 969436])
# Validation edge indices: torch.Size([2, 969436])
# Test edge indices: torch.Size([2, 17449864])
# Replacing string label at index 3448: G561
# Replacing string label at index 5191: G3633
# Replacing string label at index 12936: G2039
# Replacing string label at index 13365: G477
# Replacing string label at index 18346: G362
# Replacing string label at index 20135: G153
# Replacing string label at index 25069: G3638
# Replacing string label at index 31523: G969
# Replacing string label at index 31957: G2088
# Replacing string label at index 34882: G1942
# Replacing string label at index 35802: G1286
# Replacing string label at index 37929: G4328
# Replacing string label at index 58849: G2845
# Replacing string label at index 60574: G2452
# Replacing string label at index 61243: G586
# Replacing string label at index 65901: G2432
# Replacing string label at index 74808: G2644
# Replacing string label at index 94819: G535
# Replacing string label at index 115928: G3264
# Replacing string label at index 116931: G3382
# Replacing string label at index 118556: G3378
# Replacing string label at index 120951: G2363
# Replacing string label at index 122073: G2157
# Replacing string label at index 126173: G1703
# Replacing string label at index 126891: G2553
# Replacing string label at index 128275: G4215
# Replacing string label at index 129821: G2359
# Replacing string label at index 137123: G709
# Replacing string label at index 144474: G500
# Replacing string label at index 155548: G3152
# Replacing string label at index 157977: G313
# Replacing string label at index 158150: G4131
# Replacing string label at index 185035: G608
# Replacing string label at index 191022: G4500
# Replacing string label at index 196580: G429
# Replacing string label at index 197725: G3082
# Replacing string label at index 204736: G4392
# Replacing string label at index 206663: G2256
# Replacing string label at index 208617: G1443
# Replacing string label at index 212040: G1876
# Replacing string label at index 214706: G1978
# Replacing string label at index 215653: G4065
# Replacing string label at index 220078: G1138
# Replacing string label at index 220472: G2271
# Replacing string label at index 221542: G778
# Replacing string label at index 222184: G1991
# Replacing string label at index 222560: G1691
# Replacing string label at index 224856: G4426
# Replacing string label at index 238889: G3455
# Replacing string label at index 240568: G2686
# Replacing string label at index 246677: G1790
# Replacing string label at index 249243: G953
# Replacing string label at index 250646: G3387
# Replacing string label at index 259542: G2281
# Replacing string label at index 259741: G2225
# Replacing string label at index 264753: G1347
# Replacing string label at index 272107: G3861
# Replacing string label at index 274316: G4146
# Replacing string label at index 276863: G2245
# Replacing string label at index 277559: G4449
# Replacing string label at index 282560: G2878
# Replacing string label at index 282701: G901
# Replacing string label at index 294155: G3114
# Replacing string label at index 296376: G4377
# Replacing string label at index 297634: G3917
# Replacing string label at index 298781: G1686
# Replacing string label at index 301634: G3311
# Replacing string label at index 303128: G1257
# Replacing string label at index 304095: G3444
# Replacing string label at index 306179: G1121
# Replacing string label at index 312453: G578
# Replacing string label at index 312933: G1014
# Replacing string label at index 314336: G151
# Replacing string label at index 316395: G1194
# Replacing string label at index 317707: G2809
# Replacing string label at index 318672: G1722
# Replacing string label at index 321665: G3368
# Replacing string label at index 329916: G3606
# Replacing string label at index 331315: G258
# Replacing string label at index 334837: G3359
# Replacing string label at index 335980: G2443
# Replacing string label at index 336237: G66
# Replacing string label at index 346720: G2983
# Replacing string label at index 353741: G4316
# Replacing string label at index 362275: G2031
# Replacing string label at index 365718: G1083
# Replacing string label at index 366584: G3511
# Replacing string label at index 370319: G1032
# Replacing string label at index 382761: G1010
# Replacing string label at index 384121: G2689
# Replacing string label at index 385300: G4186
# Replacing string label at index 387446: G2489
# Replacing string label at index 388423: G4470
# Replacing string label at index 389264: G724
# Replacing string label at index 391546: G3560
# Replacing string label at index 391813: G3064
# Replacing string label at index 398120: G2285
# Replacing string label at index 399103: G271
# Replacing string label at index 401505: G968
# Replacing string label at index 402266: G3841
# Replacing string label at index 405870: G4487
# Replacing string label at index 405886: G2365
# Replacing string label at index 407434: G2038
# Replacing string label at index 408067: G4506
# Replacing string label at index 409493: G3412
# Replacing string label at index 411634: G1471
# Replacing string label at index 411867: G2203
# Replacing string label at index 414372: G3025
# Replacing string label at index 416079: G3059
# Replacing string label at index 418014: G3451
# Replacing string label at index 418516: G2546
# Replacing string label at index 423202: G4262
# Replacing string label at index 429412: G3629
# Replacing string label at index 430215: G2166
# Replacing string label at index 430547: G3773
# Replacing string label at index 432192: G403
# Replacing string label at index 435354: G200
# Replacing string label at index 450204: G4267
# Replacing string label at index 455878: G3276
# Replacing string label at index 458434: G971
# Replacing string label at index 465885: G4140
# Replacing string label at index 472091: G2215
# Replacing string label at index 490183: G2780
# Replacing string label at index 491268: G2897
# Replacing string label at index 492646: G1782
# Replacing string label at index 492671: G2693
# Replacing string label at index 494634: G979
# Replacing string label at index 498455: G136
# Replacing string label at index 499989: G2889
# Replacing string label at index 503430: G1204
# Replacing string label at index 507625: G3317
# Replacing string label at index 520377: G3852
# Replacing string label at index 523711: G1613
# Replacing string label at index 525760: G125
# Replacing string label at index 525779: G2464
# Replacing string label at index 526587: G2734
# Replacing string label at index 528913: G985
# Replacing string label at index 549542: G3770
# Replacing string label at index 552746: G4147
# Replacing string label at index 557020: G1787
# Replacing string label at index 559350: G4265
# Replacing string label at index 563184: G4057
# Replacing string label at index 580189: G1340
# Replacing string label at index 582274: G3594
# Replacing string label at index 587247: G643
# Replacing string label at index 588111: G3121
# Replacing string label at index 589321: G899
# Replacing string label at index 590977: G2912
# Replacing string label at index 596830: G3617
# Replacing string label at index 604410: G3533
# Replacing string label at index 608970: G3851
# Replacing string label at index 609156: G3415
# Replacing string label at index 611230: G2516
# Replacing string label at index 624284: G2210
# Replacing string label at index 625725: G2093
# Replacing string label at index 627114: G2913
# Replacing string label at index 628594: G1908
# Replacing string label at index 632710: G224
# Replacing string label at index 641891: G309
# Replacing string label at index 647937: G390
# Replacing string label at index 657341: G3753
# Replacing string label at index 657981: G3350
# Replacing string label at index 660760: G4477
# Replacing string label at index 662135: G4336
# Replacing string label at index 665166: G1250
# Replacing string label at index 670959: G3973
# Replacing string label at index 673684: G264
# Replacing string label at index 681031: G379
# Replacing string label at index 683828: G2169
# Replacing string label at index 686099: G2747
# Replacing string label at index 688505: G2602
# Replacing string label at index 690149: G3584
# Replacing string label at index 690494: G5
# Replacing string label at index 697621: G3290
# Replacing string label at index 697650: G3881
# Replacing string label at index 710139: G4158
# Replacing string label at index 712537: G1562
# Replacing string label at index 712602: G1240
# Replacing string label at index 714627: G2710
# Replacing string label at index 717712: G4000
# Replacing string label at index 718049: G1474
# Replacing string label at index 726428: G1173
# Replacing string label at index 731846: G2704
# Replacing string label at index 732964: G2156
# Replacing string label at index 735164: G3188
# Replacing string label at index 740706: G2390
# Replacing string label at index 746905: G775
# Replacing string label at index 754464: G1366
# Replacing string label at index 754607: G2028
# Replacing string label at index 760268: G3425
# Replacing string label at index 761293: G3419
# Replacing string label at index 765979: G4418
# Replacing string label at index 768100: G1266
# Replacing string label at index 768346: G189
# Replacing string label at index 769317: G2377
# Replacing string label at index 770127: G2682
# Replacing string label at index 775769: G3830
# Replacing string label at index 776854: G1254
# Replacing string label at index 782689: G1913
# Replacing string label at index 789083: G847
# Replacing string label at index 789748: G308
# Replacing string label at index 792470: G525
# Replacing string label at index 792731: G4376
# Replacing string label at index 797316: G1698
# Replacing string label at index 798994: G623
# Replacing string label at index 807808: G50
# Replacing string label at index 807915: G952
# Replacing string label at index 821474: G3561
# Replacing string label at index 824166: G3706
# Replacing string label at index 827532: G1819
# Replacing string label at index 840666: G3649
# Replacing string label at index 859865: G4390
# Replacing string label at index 863580: G228
# Replacing string label at index 864270: G2880
# Replacing string label at index 865282: G3213
# Replacing string label at index 872379: G2573
# Replacing string label at index 873652: G1444
# Replacing string label at index 875231: G814
# Replacing string label at index 877240: G323
# Replacing string label at index 879076: G1622
# Replacing string label at index 883437: G1875
# Replacing string label at index 890284: G1045
# Replacing string label at index 899500: G3329
# Replacing string label at index 901258: G2118
# Replacing string label at index 902630: G598
# Replacing string label at index 911905: G256
# Replacing string label at index 915579: G1744
# Replacing string label at index 917867: G1818
# Replacing string label at index 934583: G4052
# Replacing string label at index 943732: G1800
# Replacing string label at index 944239: G635
# Replacing string label at index 948533: G3547
# Replacing string label at index 951643: G835
# Replacing string label at index 958159: G3289
# Replacing string label at index 961074: G41
# Replacing string label at index 965433: G942
# Replacing string label at index 965810: G4233
# Replacing string label at index 622: G2598
# Replacing string label at index 4398: G3296
# Replacing string label at index 17634: G2675
# Replacing string label at index 18803: G1999
# Replacing string label at index 19330: G788
# Replacing string label at index 38796: G3618
# Replacing string label at index 41924: G705
# Replacing string label at index 50602: G4170
# Replacing string label at index 51858: G4047
# Replacing string label at index 55344: G3195
# Replacing string label at index 63178: G742
# Replacing string label at index 63558: G1595
# Replacing string label at index 71997: G2902
# Replacing string label at index 72907: G3711
# Replacing string label at index 77998: G621
# Replacing string label at index 84934: G1434
# Replacing string label at index 91734: G120
# Replacing string label at index 92468: G1946
# Replacing string label at index 100345: G4408
# Replacing string label at index 106175: G1821
# Replacing string label at index 109215: G442
# Replacing string label at index 109595: G452
# Replacing string label at index 112791: G3766
# Replacing string label at index 123277: G4223
# Replacing string label at index 124914: G111
# Replacing string label at index 130603: G3894
# Replacing string label at index 134373: G3228
# Replacing string label at index 134798: G1193
# Replacing string label at index 137213: G372
# Replacing string label at index 141646: G2275
# Replacing string label at index 142935: G4421
# Replacing string label at index 143993: G1251
# Replacing string label at index 147223: G1929
# Replacing string label at index 148362: G618
# Replacing string label at index 158565: G3521
# Replacing string label at index 164333: G1833
# Replacing string label at index 165121: G4063
# Replacing string label at index 181534: G2663
# Replacing string label at index 193536: G1396
# Replacing string label at index 195393: G2826
# Replacing string label at index 200248: G3818
# Replacing string label at index 204817: G288
# Replacing string label at index 207228: G3780
# Replacing string label at index 212469: G3862
# Replacing string label at index 220042: G3944
# Replacing string label at index 224171: G3400
# Replacing string label at index 225401: G860
# Replacing string label at index 226362: G3810
# Replacing string label at index 241650: G3094
# Replacing string label at index 244782: G2981
# Replacing string label at index 249532: G1435
# Replacing string label at index 253945: G1272
# Replacing string label at index 272944: G728
# Replacing string label at index 282689: G946
# Replacing string label at index 291789: G3333
# Replacing string label at index 297534: G1054
# Replacing string label at index 298335: G965
# Replacing string label at index 302543: G440
# Replacing string label at index 312386: G4399
# Replacing string label at index 314846: G1531
# Replacing string label at index 316222: G1302
# Replacing string label at index 322905: G2064
# Replacing string label at index 325394: G3022
# Replacing string label at index 327621: G3541
# Replacing string label at index 329068: G1227
# Replacing string label at index 338584: G1854
# Replacing string label at index 340634: G3880
# Replacing string label at index 344061: G2012
# Replacing string label at index 345905: G480
# Replacing string label at index 350086: G1550
# Replacing string label at index 355469: G3539
# Replacing string label at index 357851: G1648
# Replacing string label at index 362622: G3489
# Replacing string label at index 363808: G2054
# Replacing string label at index 369327: G3760
# Replacing string label at index 386195: G812
# Replacing string label at index 388785: G3957
# Replacing string label at index 389120: G4341
# Replacing string label at index 394244: G4152
# Replacing string label at index 395953: G4242
# Replacing string label at index 398127: G3676
# Replacing string label at index 398364: G769
# Replacing string label at index 400589: G357
# Replacing string label at index 401361: G2261
# Replacing string label at index 401686: G3902
# Replacing string label at index 401823: G3197
# Replacing string label at index 407525: G2148
# Replacing string label at index 408444: G3930
# Replacing string label at index 410091: G2085
# Replacing string label at index 419821: G520
# Replacing string label at index 421169: G711
# Replacing string label at index 422260: G3905
# Replacing string label at index 429441: G2628
# Replacing string label at index 431682: G3578
# Replacing string label at index 434743: G934
# Replacing string label at index 445153: G3045
# Replacing string label at index 452270: G4236
# Replacing string label at index 452701: G414
# Replacing string label at index 452727: G250
# Replacing string label at index 457885: G2659
# Replacing string label at index 463559: G2692
# Replacing string label at index 464349: G656
# Replacing string label at index 464392: G2945
# Replacing string label at index 482341: G1273
# Replacing string label at index 507345: G1603
# Replacing string label at index 507947: G2893
# Replacing string label at index 509497: G858
# Replacing string label at index 510405: G22
# Replacing string label at index 511122: G2877
# Replacing string label at index 517371: G1785
# Replacing string label at index 522511: G3140
# Replacing string label at index 523735: G3192
# Replacing string label at index 533045: G74
# Replacing string label at index 536421: G4192
# Replacing string label at index 537738: G1779
# Replacing string label at index 542197: G600
# Replacing string label at index 547022: G3484
# Replacing string label at index 551344: G1239
# Replacing string label at index 556068: G4406
# Replacing string label at index 559490: G3285
# Replacing string label at index 565522: G4451
# Replacing string label at index 565578: G3223
# Replacing string label at index 570980: G1437
# Replacing string label at index 571266: G4273
# Replacing string label at index 574866: G3563
# Replacing string label at index 576314: G1584
# Replacing string label at index 577970: G1222
# Replacing string label at index 579814: G3775
# Replacing string label at index 582206: G3041
# Replacing string label at index 589183: G883
# Replacing string label at index 593319: G2987
# Replacing string label at index 593335: G193
# Replacing string label at index 597364: G1878
# Replacing string label at index 597709: G3666
# Replacing string label at index 601938: G3664
# Replacing string label at index 608497: G338
# Replacing string label at index 609717: G381
# Replacing string label at index 612145: G3348
# Replacing string label at index 620149: G3004
# Replacing string label at index 624546: G751
# Replacing string label at index 630037: G2224
# Replacing string label at index 631630: G2109
# Replacing string label at index 635626: G1325
# Replacing string label at index 638046: G100
# Replacing string label at index 638809: G2630
# Replacing string label at index 658447: G872
# Replacing string label at index 661596: G1081
# Replacing string label at index 664275: G2258
# Replacing string label at index 664629: G3608
# Replacing string label at index 666308: G3887
# Replacing string label at index 668217: G2310
# Replacing string label at index 670553: G3015
# Replacing string label at index 675062: G1165
# Replacing string label at index 675437: G197
# Replacing string label at index 677217: G3969
# Replacing string label at index 684865: G3230
# Replacing string label at index 685157: G481
# Replacing string label at index 689868: G1692
# Replacing string label at index 690128: G3344
# Replacing string label at index 704474: G664
# Replacing string label at index 705444: G3323
# Replacing string label at index 708903: G2481
# Replacing string label at index 711163: G1298
# Replacing string label at index 720358: G303
# Replacing string label at index 727656: G3505
# Replacing string label at index 728766: G3234
# Replacing string label at index 730731: G1053
# Replacing string label at index 732528: G1428
# Replacing string label at index 733956: G305
# Replacing string label at index 757571: G3151
# Replacing string label at index 766144: G2498
# Replacing string label at index 768429: G3225
# Replacing string label at index 769648: G2649
# Replacing string label at index 770387: G1253
# Replacing string label at index 770512: G3161
# Replacing string label at index 780963: G3108
# Replacing string label at index 781399: G2479
# Replacing string label at index 782657: G3713
# Replacing string label at index 783754: G3689
# Replacing string label at index 783956: G3200
# Replacing string label at index 785073: G1495
# Replacing string label at index 786786: G4195
# Replacing string label at index 794728: G3692
# Replacing string label at index 794760: G2173
# Replacing string label at index 797362: G97
# Replacing string label at index 801402: G2708
# Replacing string label at index 805443: G1450
# Replacing string label at index 812158: G2735
# Replacing string label at index 813971: G3017
# Replacing string label at index 814236: G658
# Replacing string label at index 826037: G960
# Replacing string label at index 827796: G402
# Replacing string label at index 831292: G977
# Replacing string label at index 834250: G1002
# Replacing string label at index 838694: G1026
# Replacing string label at index 840480: G1180
# Replacing string label at index 856765: G4011
# Replacing string label at index 859907: G3204
# Replacing string label at index 862709: G3481
# Replacing string label at index 864527: G1070
# Replacing string label at index 870282: G1084
# Replacing string label at index 892958: G232
# Replacing string label at index 896697: G1515
# Replacing string label at index 900362: G2783
# Replacing string label at index 903925: G2849
# Replacing string label at index 904544: G1983
# Replacing string label at index 905347: G3430
# Replacing string label at index 910525: G3091
# Replacing string label at index 910968: G2475
# Replacing string label at index 913238: G1115
# Replacing string label at index 913624: G3307
# Replacing string label at index 916807: G1324
# Replacing string label at index 926279: G312
# Replacing string label at index 930057: G3962
# Replacing string label at index 930686: G4059
# Replacing string label at index 932293: G214
# Replacing string label at index 932352: G2430
# Replacing string label at index 939301: G3475
# Replacing string label at index 942764: G1233
# Replacing string label at index 945745: G4299
# Replacing string label at index 948669: G2469
# Replacing string label at index 962185: G1182
# Replacing string label at index 963346: G1328
# Replacing string label at index 964851: G1780
# Replacing string label at index 968307: G3956
# Replacing string label at index 2975: G2771
# Replacing string label at index 3860: G2059
# Replacing string label at index 6618: G3047
# Replacing string label at index 8651: G2980
# Replacing string label at index 13519: G1888
# Replacing string label at index 13751: G2923
# Replacing string label at index 15846: G2353
# Replacing string label at index 22011: G1922
# Replacing string label at index 22987: G4014
# Replacing string label at index 25691: G1127
# Replacing string label at index 32582: G670
# Replacing string label at index 33820: G2080
# Replacing string label at index 43035: G1721
# Replacing string label at index 48626: G3669
# Replacing string label at index 64562: G3654
# Replacing string label at index 65145: G375
# Replacing string label at index 65284: G1417
# Replacing string label at index 73588: G3053
# Replacing string label at index 88041: G1357
# Replacing string label at index 89023: G1318
# Replacing string label at index 95938: G616
# Replacing string label at index 98771: G483
# Replacing string label at index 100012: G2925
# Replacing string label at index 103232: G3141
# Replacing string label at index 105323: G2457
# Replacing string label at index 107575: G806
# Replacing string label at index 110555: G4219
# Replacing string label at index 112039: G4094
# Replacing string label at index 113584: G3372
# Replacing string label at index 115268: G630
# Replacing string label at index 126076: G855
# Replacing string label at index 128825: G2298
# Replacing string label at index 131055: G2260
# Replacing string label at index 149088: G3845
# Replacing string label at index 159128: G42
# Replacing string label at index 163279: G4150
# Replacing string label at index 171883: G1440
# Replacing string label at index 175812: G3009
# Replacing string label at index 188904: G3543
# Replacing string label at index 191397: G4446
# Replacing string label at index 197708: G1094
# Replacing string label at index 198756: G3808
# Replacing string label at index 200073: G1223
# Replacing string label at index 200521: G3997
# Replacing string label at index 204459: G3309
# Replacing string label at index 214026: G3433
# Replacing string label at index 225381: G4137
# Replacing string label at index 230482: G285
# Replacing string label at index 233084: G4093
# Replacing string label at index 249568: G1390
# Replacing string label at index 250231: G2337
# Replacing string label at index 257167: G3404
# Replacing string label at index 270929: G2120
# Replacing string label at index 272026: G1344
# Replacing string label at index 274219: G1326
# Replacing string label at index 276526: G3575
# Replacing string label at index 280228: G1669
# Replacing string label at index 289292: G799
# Replacing string label at index 292583: G1386
# Replacing string label at index 296697: G3661
# Replacing string label at index 298167: G3754
# Replacing string label at index 301348: G732
# Replacing string label at index 302344: G482
# Replacing string label at index 311308: G2956
# Replacing string label at index 311985: G582
# Replacing string label at index 325114: G687
# Replacing string label at index 329045: G3790
# Replacing string label at index 340209: G1839
# Replacing string label at index 354241: G1388
# Replacing string label at index 361355: G2998
# Replacing string label at index 362472: G4160
# Replacing string label at index 366010: G1172
# Replacing string label at index 374135: G879
# Replacing string label at index 381995: G2194
# Replacing string label at index 392626: G2707
# Replacing string label at index 401947: G4291
# Replacing string label at index 403795: G398
# Replacing string label at index 418064: G3899
# Replacing string label at index 420086: G3245
# Replacing string label at index 426286: G3609
# Replacing string label at index 427078: G3825
# Replacing string label at index 449840: G1571
# Replacing string label at index 452125: G2859
# Replacing string label at index 457927: G1804
# Replacing string label at index 458896: G978
# Replacing string label at index 460421: G3807
# Replacing string label at index 461632: G3868
# Replacing string label at index 473224: G2116
# Replacing string label at index 486381: G2409
# Replacing string label at index 487489: G6
# Replacing string label at index 487995: G3376
# Replacing string label at index 488432: G143
# Replacing string label at index 495818: G646
# Replacing string label at index 496309: G4050
# Replacing string label at index 496713: G1521
# Replacing string label at index 509144: G1154
# Replacing string label at index 510799: G2284
# Replacing string label at index 516182: G4205
# Replacing string label at index 528241: G4332
# Replacing string label at index 532181: G626
# Replacing string label at index 535313: G3945
# Replacing string label at index 537105: G4388
# Replacing string label at index 538531: G2688
# Replacing string label at index 539758: G3749
# Replacing string label at index 543294: G777
# Replacing string label at index 544527: G4157
# Replacing string label at index 551381: G317
# Replacing string label at index 556807: G4329
# Replacing string label at index 558397: G1363
# Replacing string label at index 572564: G2185
# Replacing string label at index 574957: G4429
# Replacing string label at index 584274: G2233
# Replacing string label at index 588226: G2519
# Replacing string label at index 590285: G384
# Replacing string label at index 591506: G373
# Replacing string label at index 591875: G3254
# Replacing string label at index 605906: G4075
# Replacing string label at index 606002: G921
# Replacing string label at index 606518: G4119
# Replacing string label at index 607573: G2177
# Replacing string label at index 607745: G3294
# Replacing string label at index 609280: G3903
# Replacing string label at index 611204: G4350
# Replacing string label at index 611374: G3601
# Replacing string label at index 613806: G3138
# Replacing string label at index 619750: G2255
# Replacing string label at index 625468: G2765
# Replacing string label at index 627482: G3149
# Replacing string label at index 628144: G1672
# Replacing string label at index 635469: G3940
# Replacing string label at index 639210: G2386
# Replacing string label at index 640029: G3796
# Replacing string label at index 646830: G4026
# Replacing string label at index 662068: G1645
# Replacing string label at index 668787: G3934
# Replacing string label at index 675319: G1771
# Replacing string label at index 676005: G1214
# Replacing string label at index 680145: G3612
# Replacing string label at index 683720: G4455
# Replacing string label at index 685468: G1196
# Replacing string label at index 686758: G2206
# Replacing string label at index 692527: G2569
# Replacing string label at index 700025: G595
# Replacing string label at index 706672: G1129
# Replacing string label at index 719553: G101
# Replacing string label at index 723874: G1727
# Replacing string label at index 733091: G3021
# Replacing string label at index 734670: G1759
# Replacing string label at index 742568: G4379
# Replacing string label at index 744206: G2106
# Replacing string label at index 745155: G1335
# Replacing string label at index 754464: G2131
# Replacing string label at index 759699: G3581
# Replacing string label at index 759779: G820
# Replacing string label at index 760982: G972
# Replacing string label at index 763034: G486
# Replacing string label at index 779470: G3877
# Replacing string label at index 788731: G3438
# Replacing string label at index 799116: G4423
# Replacing string label at index 802084: G1561
# Replacing string label at index 820345: G3983
# Replacing string label at index 833490: G2483
# Replacing string label at index 836573: G4164
# Replacing string label at index 841778: G206
# Replacing string label at index 846050: G1345
# Replacing string label at index 851246: G1769
# Replacing string label at index 851747: G2091
# Replacing string label at index 856782: G3906
# Replacing string label at index 859882: G3559
# Replacing string label at index 863109: G498
# Replacing string label at index 869480: G4130
# Replacing string label at index 872678: G2076
# Replacing string label at index 878249: G678
# Replacing string label at index 886851: G2055
# Replacing string label at index 888863: G1389
# Replacing string label at index 903769: G3838
# Replacing string label at index 905883: G2960
# Replacing string label at index 910524: G1858
# Replacing string label at index 913766: G1309
# Replacing string label at index 922529: G2565
# Replacing string label at index 925567: G35
# Replacing string label at index 936227: G2930
# Replacing string label at index 937241: G2623
# Replacing string label at index 938133: G2701
# Replacing string label at index 938311: G2480
# Replacing string label at index 944582: G1012
# Replacing string label at index 947863: G1617
# Replacing string label at index 950460: G2959
# Replacing string label at index 956797: G791
# Replacing string label at index 960949: G679
# Replacing string label at index 969873: G2769
# Replacing string label at index 970444: G2718
# Replacing string label at index 972008: G1841
# Replacing string label at index 974598: G3836
# Replacing string label at index 984143: G1135
# Replacing string label at index 992925: G991
# Replacing string label at index 998399: G1696
# Replacing string label at index 1010204: G701
# Replacing string label at index 1010961: G3093
# Replacing string label at index 1012742: G2199
# Replacing string label at index 1013132: G2257
# Replacing string label at index 1017292: G3163
# Replacing string label at index 1018271: G1021
# Replacing string label at index 1022626: G961
# Replacing string label at index 1027981: G1602
# Replacing string label at index 1029953: G3235
# Replacing string label at index 1031050: G2781
# Replacing string label at index 1032351: G4461
# Replacing string label at index 1033051: G1242
# Replacing string label at index 1036749: G1945
# Replacing string label at index 1047884: G2265
# Replacing string label at index 1064726: G3150
# Replacing string label at index 1074319: G830
# Replacing string label at index 1087113: G2295
# Replacing string label at index 1093530: G1139
# Replacing string label at index 1093935: G4114
# Replacing string label at index 1097755: G2144
# Replacing string label at index 1101041: G1016
# Replacing string label at index 1108901: G2013
# Replacing string label at index 1109055: G3321
# Replacing string label at index 1109542: G1076
# Replacing string label at index 1114136: G468
# Replacing string label at index 1114417: G3465
# Replacing string label at index 1116218: G4398
# Replacing string label at index 1120421: G1504
# Replacing string label at index 1121610: G2487
# Replacing string label at index 1123313: G2193
# Replacing string label at index 1127360: G3280
# Replacing string label at index 1129464: G2078
# Replacing string label at index 1132615: G284
# Replacing string label at index 1133512: G1217
# Replacing string label at index 1138184: G1206
# Replacing string label at index 1142743: G1984
# Replacing string label at index 1145104: G3115
# Replacing string label at index 1155027: G424
# Replacing string label at index 1162977: G3071
# Replacing string label at index 1175565: G2495
# Replacing string label at index 1175967: G2048
# Replacing string label at index 1177730: G1688
# Replacing string label at index 1181320: G715
# Replacing string label at index 1181436: G2375
# Replacing string label at index 1193402: G4090
# Replacing string label at index 1195010: G910
# Replacing string label at index 1196376: G3801
# Replacing string label at index 1198433: G617
# Replacing string label at index 1199018: G648
# Replacing string label at index 1202027: G432
# Replacing string label at index 1202897: G4490
# Replacing string label at index 1210983: G1407
# Replacing string label at index 1224531: G2022
# Replacing string label at index 1224655: G1490
# Replacing string label at index 1225367: G1657
# Replacing string label at index 1226622: G3365
# Replacing string label at index 1226757: G181
# Replacing string label at index 1228326: G437
# Replacing string label at index 1231321: G1079
# Replacing string label at index 1237936: G73
# Replacing string label at index 1240252: G2697
# Replacing string label at index 1242790: G14
# Replacing string label at index 1247020: G261
# Replacing string label at index 1253086: G3986
# Replacing string label at index 1254268: G3113
# Replacing string label at index 1257794: G3982
# Replacing string label at index 1271980: G3044
# Replacing string label at index 1275547: G2679
# Replacing string label at index 1280255: G3586
# Replacing string label at index 1284004: G762
# Replacing string label at index 1289102: G103
# Replacing string label at index 1294696: G1735
# Replacing string label at index 1295507: G4407
# Replacing string label at index 1303452: G3842
# Replacing string label at index 1315485: G622
# Replacing string label at index 1318798: G1756
# Replacing string label at index 1321457: G2327
# Replacing string label at index 1323005: G1902
# Replacing string label at index 1324839: G1987
# Replacing string label at index 1328358: G2304
# Replacing string label at index 1332513: G1545
# Replacing string label at index 1341042: G2990
# Replacing string label at index 1342181: G2143
# Replacing string label at index 1344011: G469
# Replacing string label at index 1344159: G122
# Replacing string label at index 1349002: G1051
# Replacing string label at index 1350547: G4495
# Replacing string label at index 1352736: G3721
# Replacing string label at index 1355049: G4156
# Replacing string label at index 1358254: G1256
# Replacing string label at index 1358886: G1306
# Replacing string label at index 1359120: G184
# Replacing string label at index 1372671: G2532
# Replacing string label at index 1375662: G1042
# Replacing string label at index 1377329: G1741
# Replacing string label at index 1378288: G1812
# Replacing string label at index 1382508: G4320
# Replacing string label at index 1393930: G1925
# Replacing string label at index 1395593: G4169
# Replacing string label at index 1395932: G2123
# Replacing string label at index 1405528: G2155
# Replacing string label at index 1405921: G706
# Replacing string label at index 1411978: G1718
# Replacing string label at index 1424935: G2811
# Replacing string label at index 1437158: G1815
# Replacing string label at index 1442714: G4484
# Replacing string label at index 1444381: G2870
# Replacing string label at index 1445063: G1008
# Replacing string label at index 1445733: G1416
# Replacing string label at index 1457030: G574
# Replacing string label at index 1458979: G3301
# Replacing string label at index 1460018: G3471
# Replacing string label at index 1476166: G4389
# Replacing string label at index 1487867: G1859
# Replacing string label at index 1488566: G4286
# Replacing string label at index 1493249: G48
# Replacing string label at index 1495120: G1885
# Replacing string label at index 1495782: G2015
# Replacing string label at index 1514484: G1640
# Replacing string label at index 1518801: G1673
# Replacing string label at index 1518934: G4089
# Replacing string label at index 1524409: G3538
# Replacing string label at index 1529440: G2759
# Replacing string label at index 1536844: G4293
# Replacing string label at index 1545204: G505
# Replacing string label at index 1546432: G2428
# Replacing string label at index 1548247: G750
# Replacing string label at index 1552245: G3545
# Replacing string label at index 1557393: G4144
# Replacing string label at index 1561793: G1087
# Replacing string label at index 1564306: G3397
# Replacing string label at index 1568185: G1063
# Replacing string label at index 1571424: G1806
# Replacing string label at index 1582773: G1442
# Replacing string label at index 1584273: G3026
# Replacing string label at index 1591249: G2041
# Replacing string label at index 1594839: G3681
# Replacing string label at index 1595524: G3085
# Replacing string label at index 1597166: G2380
# Replacing string label at index 1598537: G3535
# Replacing string label at index 1598637: G2269
# Replacing string label at index 1604390: G1863
# Replacing string label at index 1604626: G1958
# Replacing string label at index 1604982: G456
# Replacing string label at index 1608901: G4438
# Replacing string label at index 1620469: G2151
# Replacing string label at index 1624403: G4482
# Replacing string label at index 1626122: G3458
# Replacing string label at index 1627302: G19
# Replacing string label at index 1632715: G2800
# Replacing string label at index 1638287: G135
# Replacing string label at index 1642489: G311
# Replacing string label at index 1644223: G4312
# Replacing string label at index 1646134: G842
# Replacing string label at index 1647754: G4132
# Replacing string label at index 1650189: G2072
# Replacing string label at index 1662642: G1520
# Replacing string label at index 1663958: G1124
# Replacing string label at index 1664361: G1031
# Replacing string label at index 1664552: G3911
# Replacing string label at index 1669735: G3440
# Replacing string label at index 1677214: G1105
# Replacing string label at index 1681096: G4375
# Replacing string label at index 1681328: G657
# Replacing string label at index 1682741: G3734
# Replacing string label at index 1684243: G1145
# Replacing string label at index 1684935: G2854
# Replacing string label at index 1705480: G37
# Replacing string label at index 1714339: G3909
# Replacing string label at index 1715936: G2921
# Replacing string label at index 1716120: G2588
# Replacing string label at index 1728513: G1717
# Replacing string label at index 1730102: G450
# Replacing string label at index 1730776: G2982
# Replacing string label at index 1733220: G510
# Replacing string label at index 1735301: G306
# Replacing string label at index 1741243: G3817
# Replacing string label at index 1749823: G1615
# Replacing string label at index 1753137: G591
# Replacing string label at index 1754542: G2746
# Replacing string label at index 1763199: G2778
# Replacing string label at index 1763279: G4091
# Replacing string label at index 1765593: G3160
# Replacing string label at index 1767241: G4228
# Replacing string label at index 1767378: G3523
# Replacing string label at index 1778493: G710
# Replacing string label at index 1780553: G554
# Replacing string label at index 1788217: G3426
# Replacing string label at index 1791171: G491
# Replacing string label at index 1810771: G4066
# Replacing string label at index 1813424: G3778
# Replacing string label at index 1835394: G3967
# Replacing string label at index 1841195: G4290
# Replacing string label at index 1841640: G1336
# Replacing string label at index 1845612: G488
# Replacing string label at index 1850799: G2604
# Replacing string label at index 1862284: G168
# Replacing string label at index 1869248: G3797
# Replacing string label at index 1876140: G2732
# Replacing string label at index 1879704: G2391
# Replacing string label at index 1888080: G1799
# Replacing string label at index 1888941: G2308
# Replacing string label at index 1890142: G2348
# Replacing string label at index 1891924: G2387
# Replacing string label at index 1892638: G3799
# Replacing string label at index 1894019: G1716
# Replacing string label at index 1895441: G528
# Replacing string label at index 1898668: G919
# Replacing string label at index 1905720: G2347
# Replacing string label at index 1909389: G1038
# Replacing string label at index 1914658: G2578
# Replacing string label at index 1914792: G179
# Replacing string label at index 1916007: G353
# Replacing string label at index 1917644: G3256
# Replacing string label at index 1921982: G1157
# Replacing string label at index 1922786: G3519
# Replacing string label at index 1934998: G2838
# Replacing string label at index 1942900: G825
# Replacing string label at index 1949523: G3613
# Replacing string label at index 1957641: G3908
# Replacing string label at index 1960133: G165
# Replacing string label at index 1961567: G719
# Replacing string label at index 1968792: G1904
# Replacing string label at index 1969104: G1457
# Replacing string label at index 1969144: G690
# Replacing string label at index 1969272: G2936
# Replacing string label at index 1973850: G4277
# Replacing string label at index 1975415: G2268
# Replacing string label at index 1976719: G3011
# Replacing string label at index 1981958: G2239
# Replacing string label at index 1990814: G1043
# Replacing string label at index 1992456: G2283
# Replacing string label at index 1992883: G16
# Replacing string label at index 1996944: G2543
# Replacing string label at index 1998242: G1486
# Replacing string label at index 2000618: G2147
# Replacing string label at index 2005132: G2857
# Replacing string label at index 2005537: G1802
# Replacing string label at index 2012758: G3822
# Replacing string label at index 2014879: G2191
# Replacing string label at index 2015907: G4197
# Replacing string label at index 2018313: G1837
# Replacing string label at index 2021904: G1020
# Replacing string label at index 2023815: G1131
# Replacing string label at index 2034141: G2825
# Replacing string label at index 2037171: G1635
# Replacing string label at index 2037340: G2503
# Replacing string label at index 2039147: G3336
# Replacing string label at index 2040314: G4002
# Replacing string label at index 2049877: G1752
# Replacing string label at index 2053056: G8
# Replacing string label at index 2054930: G230
# Replacing string label at index 2058548: G614
# Replacing string label at index 2063229: G1813
# Replacing string label at index 2067698: G2684
# Replacing string label at index 2078181: G3089
# Replacing string label at index 2097432: G157
# Replacing string label at index 2107638: G1316
# Replacing string label at index 2108352: G3424
# Replacing string label at index 2109543: G2900
# Replacing string label at index 2116362: G2160
# Replacing string label at index 2118928: G3253
# Replacing string label at index 2122064: G3176
# Replacing string label at index 2129523: G2477
# Replacing string label at index 2130136: G3916
# Replacing string label at index 2149461: G1726
# Replacing string label at index 2153724: G3910
# Replacing string label at index 2157900: G126
# Replacing string label at index 2164535: G3815
# Replacing string label at index 2165978: G2341
# Replacing string label at index 2173523: G2656
# Replacing string label at index 2173791: G2393
# Replacing string label at index 2175302: G304
# Replacing string label at index 2176730: G2335
# Replacing string label at index 2177857: G2601
# Replacing string label at index 2188211: G2940
# Replacing string label at index 2188302: G2647
# Replacing string label at index 2189706: G53
# Replacing string label at index 2196009: G2435
# Replacing string label at index 2200903: G3172
# Replacing string label at index 2203362: G1212
# Replacing string label at index 2209493: G1447
# Replacing string label at index 2215816: G2004
# Replacing string label at index 2218849: G3027
# Replacing string label at index 2230167: G2097
# Replacing string label at index 2230637: G2084
# Replacing string label at index 2235287: G607
# Replacing string label at index 2236538: G763
# Replacing string label at index 2237981: G887
# Replacing string label at index 2241610: G790
# Replacing string label at index 2252245: G3840
# Replacing string label at index 2265191: G2219
# Replacing string label at index 2265272: G262
# Replacing string label at index 2286895: G3672
# Replacing string label at index 2293865: G1028
# Replacing string label at index 2295681: G474
# Replacing string label at index 2306070: G3674
# Replacing string label at index 2309865: G3258
# Replacing string label at index 2310151: G2541
# Replacing string label at index 2312704: G3300
# Replacing string label at index 2322922: G2621
# Replacing string label at index 2328460: G3735
# Replacing string label at index 2332438: G1075
# Replacing string label at index 2333092: G1065
# Replacing string label at index 2333613: G2366
# Replacing string label at index 2334419: G3979
# Replacing string label at index 2335622: G2844
# Replacing string label at index 2336388: G3278
# Replacing string label at index 2339042: G2071
# Replacing string label at index 2360461: G3971
# Replacing string label at index 2363073: G4385
# Replacing string label at index 2363296: G3794
# Replacing string label at index 2363867: G4175
# Replacing string label at index 2368887: G2721
# Replacing string label at index 2371396: G4268
# Replacing string label at index 2373796: G418
# Replacing string label at index 2376297: G3747
# Replacing string label at index 2381056: G4281
# Replacing string label at index 2381958: G3556
# Replacing string label at index 2385929: G4340
# Replacing string label at index 2386368: G1574
# Replacing string label at index 2387783: G3628
# Replacing string label at index 2388107: G1033
# Replacing string label at index 2394960: G2976
# Replacing string label at index 2394962: G2895
# Replacing string label at index 2398366: G2957
# Replacing string label at index 2398960: G4459
# Replacing string label at index 2401836: G944
# Replacing string label at index 2407633: G2195
# Replacing string label at index 2416156: G3476
# Replacing string label at index 2423446: G394
# Replacing string label at index 2425590: G2542
# Replacing string label at index 2431327: G1873
# Replacing string label at index 2431863: G2911
# Replacing string label at index 2435143: G854
# Replacing string label at index 2447607: G1906
# Replacing string label at index 2458753: G3645
# Replacing string label at index 2460262: G2241
# Replacing string label at index 2462275: G4437
# Replacing string label at index 2463394: G2445
# Replacing string label at index 2467374: G2128
# Replacing string label at index 2467501: G1144
# Replacing string label at index 2480216: G17
# Replacing string label at index 2485339: G2744
# Replacing string label at index 2485882: G253
# Replacing string label at index 2489807: G2926
# Replacing string label at index 2495004: G2334
# Replacing string label at index 2497710: G465
# Replacing string label at index 2501178: G4061
# Replacing string label at index 2501637: G2164
# Replacing string label at index 2507308: G2963
# Replacing string label at index 2507530: G1591
# Replacing string label at index 2508768: G3109
# Replacing string label at index 2518745: G2999
# Replacing string label at index 2523121: G3774
# Replacing string label at index 2526659: G660
# Replacing string label at index 2534277: G3637
# Replacing string label at index 2541407: G4182
# Replacing string label at index 2545161: G24
# Replacing string label at index 2551482: G2551
# Replacing string label at index 2559554: G3727
# Replacing string label at index 2561542: G1981
# Replacing string label at index 2563661: G366
# Replacing string label at index 2565457: G2471
# Replacing string label at index 2567450: G3420
# Replacing string label at index 2567835: G722
# Replacing string label at index 2583119: G3132
# Replacing string label at index 2584917: G1820
# Replacing string label at index 2585216: G1255
# Replacing string label at index 2587802: G3043
# Replacing string label at index 2589365: G3933
# Replacing string label at index 2589693: G3972
# Replacing string label at index 2603224: G87
# Replacing string label at index 2604447: G2751
# Replacing string label at index 2604872: G1659
# Replacing string label at index 2612421: G4304
# Replacing string label at index 2613896: G3268
# Replacing string label at index 2617125: G396
# ...
# Replacing string label at index 16056304: G3487
# Replacing string label at index 16062148: G3181
# Replacing string label at index 16071973: G219
# Replacing string label at index 16085349: G3389
# Replacing string label at index 16085750: G3590
# Replacing string label at index 16088861: G1174
# Replacing string label at index 16090080: G3184
# Replacing string label at index 16110927: G1907
# Replacing string label at index 16113171: G3352
# Replacing string label at index 16114151: G1232
# Replacing string label at index 16123230: G2874
# Replacing string label at index 16128291: G2590
# Replacing string label at index 16130561: G2670
# Replacing string label at index 16131800: G1590
# Replacing string label at index 16133214: G3335
# Replacing string label at index 16133650: G1689
# Replacing string label at index 16137317: G3395
# Replacing string label at index 16137709: G316
# Replacing string label at index 16141317: G235
# Replacing string label at index 16146382: G2571
# Replacing string label at index 16147075: G2152
# Replacing string label at index 16150793: G2035
# Replacing string label at index 16151902: G1039
# Replacing string label at index 16154012: G605
# Replacing string label at index 16155734: G1670
# Replacing string label at index 16156341: G1976
# Replacing string label at index 16162338: G497
# Replacing string label at index 16173096: G4129
# Replacing string label at index 16175268: G3647
# Replacing string label at index 16177327: G602
# Replacing string label at index 16179122: G3483
# Replacing string label at index 16179355: G2092
# Replacing string label at index 16179694: G1743
# Replacing string label at index 16188723: G4232
# Replacing string label at index 16189378: G1034
# Replacing string label at index 16203033: G1560
# Replacing string label at index 16203847: G3477
# Replacing string label at index 16204424: G3884
# Replacing string label at index 16212481: G950
# Replacing string label at index 16213455: G1516
# Replacing string label at index 16213513: G1292
# Replacing string label at index 16224389: G300
# Replacing string label at index 16224942: G736
# Replacing string label at index 16227707: G2370
# Replacing string label at index 16238887: G1458
# Replacing string label at index 16243584: G915
# Replacing string label at index 16257139: G737
# Replacing string label at index 16258335: G3075
# Replacing string label at index 16262729: G1827
# Replacing string label at index 16266007: G3800
# Replacing string label at index 16275936: G1985
# Replacing string label at index 16278200: G3509
# Replacing string label at index 16285062: G3331
# Replacing string label at index 16293981: G2958
# Replacing string label at index 16295129: G2105
# Replacing string label at index 16296852: G1208
# Replacing string label at index 16305056: G1060
# Replacing string label at index 16314535: G65
# Replacing string label at index 16326738: G2419
# Replacing string label at index 16330197: G1017
# Replacing string label at index 16332626: G2523
# Replacing string label at index 16338218: G1901
# Replacing string label at index 16349415: G549
# Replacing string label at index 16355539: G2872
# Replacing string label at index 16358532: G2853
# Replacing string label at index 16360626: G1993
# Replacing string label at index 16361556: G2805
# Replacing string label at index 16363101: G1949
# Replacing string label at index 16370804: G704
# Replacing string label at index 16371424: G3837
# Replacing string label at index 16378572: G1188
# Replacing string label at index 16386932: G2288
# Replacing string label at index 16398018: G4082
# Replacing string label at index 16398454: G572
# Replacing string label at index 16406739: G4053
# Replacing string label at index 16407191: G1738
# Replacing string label at index 16410084: G108
# Replacing string label at index 16412947: G496
# Replacing string label at index 16415880: G1078
# Replacing string label at index 16418458: G2044
# Replacing string label at index 16425060: G352
# Replacing string label at index 16432787: G3236
# Replacing string label at index 16435869: G2222
# Replacing string label at index 16442006: G3582
# Replacing string label at index 16457695: G2552
# Replacing string label at index 16461279: G4496
# Replacing string label at index 16462198: G1327
# Replacing string label at index 16464644: G1367
# Replacing string label at index 16467046: G3698
# Replacing string label at index 16485745: G3207
# Replacing string label at index 16491697: G1917
# Replacing string label at index 16492317: G1264
# Replacing string label at index 16493360: G1714
# Replacing string label at index 16498463: G1869
# Replacing string label at index 16501794: G2183
# Replacing string label at index 16502526: G2415
# Replacing string label at index 16503266: G2740
# Replacing string label at index 16509252: G1262
# Replacing string label at index 16517382: G1265
# Replacing string label at index 16518603: G4347
# Replacing string label at index 16521567: G3248
# Replacing string label at index 16531396: G4199
# Replacing string label at index 16532740: G3562
# Replacing string label at index 16533589: G1851
# Replacing string label at index 16538361: G2773
# Replacing string label at index 16542486: G4463
# Replacing string label at index 16558054: G4051
# Replacing string label at index 16559315: G2124
# Replacing string label at index 16563727: G3403
# Replacing string label at index 16568206: G40
# Replacing string label at index 16577274: G655
# Replacing string label at index 16579249: G4174
# Replacing string label at index 16582777: G2851
# Replacing string label at index 16586289: G876
# Replacing string label at index 16591384: G2243
# Replacing string label at index 16592799: G185
# Replacing string label at index 16593043: G931
# Replacing string label at index 16594022: G3098
# Replacing string label at index 16596449: G545
# Replacing string label at index 16603852: G4275
# Replacing string label at index 16607753: G1494
# Replacing string label at index 16610554: G1472
# Replacing string label at index 16621278: G3402
# Replacing string label at index 16635026: G4302
# Replacing string label at index 16637586: G4510
# Replacing string label at index 16654368: G4497
# Replacing string label at index 16657187: G3162
# Replacing string label at index 16659332: G1268
# Replacing string label at index 16667929: G1761
# Replacing string label at index 16669118: G3222
# Replacing string label at index 16672756: G1881
# Replacing string label at index 16673799: G3994
# Replacing string label at index 16674704: G3006
# Replacing string label at index 16676471: G11
# Replacing string label at index 16677658: G107
# Replacing string label at index 16678042: G1530
# Replacing string label at index 16679833: G3106
# Replacing string label at index 16679926: G2095
# Replacing string label at index 16681286: G2753
# Replacing string label at index 16690152: G1294
# Replacing string label at index 16692391: G1943
# Replacing string label at index 16698445: G1919
# Replacing string label at index 16702273: G2608
# Replacing string label at index 16708524: G3546
# Replacing string label at index 16713332: G2917
# Replacing string label at index 16715196: G1158
# Replacing string label at index 16715347: G1289
# Replacing string label at index 16721967: G1995
# Replacing string label at index 16725188: G821
# Replacing string label at index 16730451: G2174
# Replacing string label at index 16732003: G2361
# Replacing string label at index 16733981: G2450
# Replacing string label at index 16740352: G3718
# Replacing string label at index 16749536: G4190
# Replacing string label at index 16758047: G7
# Replacing string label at index 16760246: G739
# Replacing string label at index 16761136: G346
# Replacing string label at index 16764357: G31
# Replacing string label at index 16766788: G1566
# Replacing string label at index 16767888: G3746
# Replacing string label at index 16773744: G882
# Replacing string label at index 16774178: G3318
# Replacing string label at index 16781367: G1300
# Replacing string label at index 16783174: G139
# Replacing string label at index 16787161: G4386
# Replacing string label at index 16787877: G980
# Replacing string label at index 16791166: G2717
# Replacing string label at index 16792850: G2953
# Replacing string label at index 16799609: G4370
# Replacing string label at index 16801404: G4448
# Replacing string label at index 16808081: G2882
# Replacing string label at index 16815103: G1261
# Replacing string label at index 16817512: G970
# Replacing string label at index 16818268: G1952
# Replacing string label at index 16821911: G3127
# Replacing string label at index 16824666: G807
# Replacing string label at index 16826182: G1200
# Replacing string label at index 16828806: G2672
# Replacing string label at index 16832873: G2884
# Replacing string label at index 16843694: G940
# Replacing string label at index 16844959: G3893
# Replacing string label at index 16844966: G3103
# Replacing string label at index 16852856: G4457
# Replacing string label at index 16860493: G1939
# Replacing string label at index 16866364: G754
# Replacing string label at index 16872661: G177
# Replacing string label at index 16881274: G1480
# Replacing string label at index 16882256: G272
# Replacing string label at index 16887870: G252
# Replacing string label at index 16891488: G3241
# Replacing string label at index 16895072: G2135
# Replacing string label at index 16896547: G3963
# Replacing string label at index 16896942: G1400
# Replacing string label at index 16898690: G3769
# Replacing string label at index 16899615: G1573
# Replacing string label at index 16899869: G2904
# Replacing string label at index 16903705: G1116
# Replacing string label at index 16912936: G1331
# Replacing string label at index 16913381: G23
# Replacing string label at index 16914653: G3460
# Replacing string label at index 16916490: G694
# Replacing string label at index 16920913: G2685
# Replacing string label at index 16921821: G1279
# Replacing string label at index 16923432: G2229
# Replacing string label at index 16926794: G4278
# Replacing string label at index 16930568: G3385
# Replacing string label at index 16931527: G2970
# Replacing string label at index 16935919: G3648
# Replacing string label at index 16940482: G295
# Replacing string label at index 16945090: G4224
# Replacing string label at index 16968970: G3137
# Replacing string label at index 16969572: G3857
# Replacing string label at index 16975059: G4072
# Replacing string label at index 16979641: G4344
# Replacing string label at index 16986283: G4479
# Replacing string label at index 16986919: G3474
# Replacing string label at index 16987821: G4420
# Replacing string label at index 16988583: G1540
# Replacing string label at index 16988876: G3984
# Replacing string label at index 16993433: G4081
# Replacing string label at index 16994701: G296
# Replacing string label at index 16997292: G1964
# Replacing string label at index 16998502: G1767
# Replacing string label at index 17001619: G2418
# Replacing string label at index 17006047: G356
# Replacing string label at index 17020609: G3750
# Replacing string label at index 17023112: G3206
# Replacing string label at index 17028144: G861
# Replacing string label at index 17031583: G4128
# Replacing string label at index 17034319: G3855
# Replacing string label at index 17035231: G4136
# Replacing string label at index 17042897: G2789
# Replacing string label at index 17046932: G433
# Replacing string label at index 17053520: G2648
# Replacing string label at index 17056763: G4154
# Replacing string label at index 17057294: G161
# Replacing string label at index 17059505: G4087
# Replacing string label at index 17059544: G4360
# Replacing string label at index 17068675: G1517
# Replacing string label at index 17073381: G1959
# Replacing string label at index 17074597: G2627
# Replacing string label at index 17078085: G667
# Replacing string label at index 17079291: G1479
# Replacing string label at index 17080806: G4212
# Replacing string label at index 17082830: G2529
# Replacing string label at index 17083569: G1125
# Replacing string label at index 17087755: G341
# Replacing string label at index 17107014: G792
# Replacing string label at index 17107256: G2500
# Replacing string label at index 17115247: G733
# Replacing string label at index 17117797: G1211
# Replacing string label at index 17120945: G1137
# Replacing string label at index 17121467: G4468
# Replacing string label at index 17121682: G2943
# Replacing string label at index 17124316: G360
# Replacing string label at index 17130459: G4255
# Replacing string label at index 17134940: G1058
# Replacing string label at index 17143812: G3892
# Replacing string label at index 17149531: G1766
# Replacing string label at index 17150059: G3789
# Replacing string label at index 17151520: G1191
# Replacing string label at index 17156094: G198
# Replacing string label at index 17157984: G4080
# Replacing string label at index 17160102: G3695
# Replacing string label at index 17170194: G837
# Replacing string label at index 17172137: G3201
# Replacing string label at index 17172401: G1572
# Replacing string label at index 17181381: G566
# Replacing string label at index 17184028: G633
# Replacing string label at index 17186856: G3863
# Replacing string label at index 17217116: G3354
# Replacing string label at index 17218798: G2142
# Replacing string label at index 17220068: G3479
# Replacing string label at index 17221647: G3136
# Replacing string label at index 17222987: G3351
# Replacing string label at index 17223186: G3010
# Replacing string label at index 17229095: G3932
# Replacing string label at index 17229898: G3795
# Replacing string label at index 17233061: G455
# Replacing string label at index 17234044: G2650
# Replacing string label at index 17236990: G4358
# Replacing string label at index 17241816: G2830
# Replacing string label at index 17246126: G1313
# Replacing string label at index 17257005: G746
# Replacing string label at index 17258013: G1314
# Replacing string label at index 17260666: G1432
# Replacing string label at index 17263469: G1134
# Replacing string label at index 17267293: G1772
# Replacing string label at index 17267834: G2378
# Replacing string label at index 17271977: G831
# Replacing string label at index 17274681: G3990
# Replacing string label at index 17276427: G1798
# Replacing string label at index 17281307: G4411
# Replacing string label at index 17295145: G3640
# Replacing string label at index 17305937: G558
# Replacing string label at index 17315748: G1411
# Replacing string label at index 17316416: G904
# Replacing string label at index 17321282: G1303
# Replacing string label at index 17327800: G325
# Replacing string label at index 17340926: G365
# Replacing string label at index 17346473: G3992
# Replacing string label at index 17372523: G2163
# Replacing string label at index 17380540: G487
# Replacing string label at index 17401064: G2984
# Replacing string label at index 17401240: G3434
# Replacing string label at index 17411318: G2916
# Replacing string label at index 17414859: G2723
# Replacing string label at index 17422388: G4184
# Replacing string label at index 17424669: G2867
# Replacing string label at index 17428331: G2549
# Replacing string label at index 17433009: G4333
# Replacing string label at index 17435682: G3190
# Replacing string label at index 17439647: G1271
# Replacing string label at index 17441452: G3737
# Replacing string label at index 17442786: G247
# Replacing string label at index 17447654: G1511
# Training data: Data(x=[4511, 805], edge_index=[2, 969436], edge_attr=[969436], y=[969436])
# Validation data: Data(x=[4511, 805], edge_index=[2, 969436], edge_attr=[969436], y=[969436])
# Test data: Data(x=[4511, 805], edge_index=[2, 17449864], edge_attr=[17449864], y=[17449864])
# Training node features shape: torch.Size([4511, 805])
# Training edge index shape: torch.Size([2, 969436])
# Training edge weight shape: torch.Size([969436])
# Training labels shape: torch.Size([969436])
# Validation node features shape: torch.Size([4511, 805])
# Validation edge index shape: torch.Size([2, 969436])
# Validation edge weight shape: torch.Size([969436])
# Validation labels shape: torch.Size([969436])
# Test node features shape: torch.Size([4511, 805])
# Test edge index shape: torch.Size([2, 17449864])
# Test edge weight shape: torch.Size([17449864])
# Test labels shape: torch.Size([17449864])

# %%
from torch_geometric.data import DataLoader
# Prepare the DataLoader for PyTorch Geometric Data objects (for train, validation, test)
train_loader = DataLoader([train_data], batch_size=1, shuffle=True)
val_loader = DataLoader([val_data], batch_size=1, shuffle=False)
test_loader = DataLoader([test_data], batch_size=1, shuffle=False)

# %%
from torch_geometric.nn import GCNConv, GATConv, global_mean_pool, GraphConv
import torch
import torch.nn as nn
import torch.optim as optim
from torch_geometric.data import DataLoader
import matplotlib.pyplot as plt

# Define the Enhanced Graph Autoencoder with regularization and attention-based enhancements
class EnhancedGraphAutoencoder(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(EnhancedGraphAutoencoder, self).__init__()

        # Encoder: Combination of GCN and GAT layers with skip connections
        self.encoder_gcn1 = GCNConv(input_dim, hidden_dim * 2, add_self_loops=True, normalize=True)
        self.encoder_gat = GATConv(hidden_dim * 2, hidden_dim, heads=4, concat=False, dropout=0.3)
        self.encoder_gat2 = GATConv(hidden_dim, hidden_dim, heads=4, concat=False, dropout=0.3)

        # Latent space: A non-linear transformation of the combined embeddings
        self.latent_transform = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim * 2),
            nn.ReLU(),
            nn.Linear(hidden_dim * 2, hidden_dim)
        )

        # Decoder: Multi-layer perceptron with ReLU activations and dropout
        self.decoder = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim * 2),
            nn.ReLU(),
            nn.Dropout(0.5),  # Apply dropout
            nn.Linear(hidden_dim * 2, input_dim)
        )

        # Residual connection (identity mapping)
        self.residual = nn.Linear(input_dim, input_dim)

        # Regularization (Laplacian smoothing penalty)
        self.laplacian_penalty = 1e-3

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        # Propagation and transformation in the encoder
        x_gcn = self.encoder_gcn1(x, edge_index)
        x_gcn = torch.relu(x_gcn)
        x_gat = self.encoder_gat(x_gcn, edge_index)
        x_gat2 = self.encoder_gat2(x_gat, edge_index)

        # Latent space transformation
        latent = self.latent_transform(x_gat2)

        # Decoding and residual mapping
        decoded = self.decoder(latent)
        decoded_residual = self.residual(data.x)

        return decoded + decoded_residual, latent  # Return decoded matrix and latent embeddings

    def compute_laplacian_loss(self, x, edge_index):
        # Compute smoothness penalty using Laplacian
        row, col = edge_index
        diff = x[row] - x[col]
        laplacian_loss = self.laplacian_penalty * torch.sum(torch.norm(diff, dim=1) ** 2)
        return laplacian_loss

# Initialize the model, optimizer, and loss function
input_dim = node_features.shape[1]  # Number of input features (genes)
hidden_dim = 256  # Latent space dimension

model = EnhancedGraphAutoencoder(input_dim=input_dim, hidden_dim=hidden_dim).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
criterion = nn.MSELoss()

# Training loop with Laplacian loss and advanced regularization
def train_autoencoder(train_loader, val_loader, model, optimizer, criterion, num_epochs=200):
    train_losses = []
    val_losses = []
    
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for data in train_loader:
            data = data.to(device)
            optimizer.zero_grad()
            
            # Forward pass
            output, embeddings = model(data)
            loss = criterion(output, data.x)  # Reconstruction loss
            
            # Add Laplacian regularization
            laplacian_loss = model.compute_laplacian_loss(embeddings, data.edge_index)
            total_loss = loss + laplacian_loss
            
            total_loss.backward()
            optimizer.step()
            running_loss += total_loss.item()

        # Log training loss
        train_losses.append(running_loss / len(train_loader))
        
        # Validation loss
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for data in val_loader:
                data = data.to(device)
                output, _ = model(data)
                loss = criterion(output, data.x)
                val_loss += loss.item()
        val_losses.append(val_loss / len(val_loader))
        
        print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}')
    
    return train_losses, val_losses

# Train the enhanced model
train_losses, val_losses = train_autoencoder(train_loader, val_loader, model, optimizer, criterion)

# Plot Training and Validation Loss
plt.figure()
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss')
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_auc_score, average_precision_score, matthews_corrcoef
import numpy as np
import torch

# Function to calculate AUPR, AUROC, and MCC
def calculate_metrics(val_data, model, device):
    model.eval()
    
    y_true = []  # Ground truth labels
    y_pred = []  # Predicted labels
    
    with torch.no_grad():
        for data in val_data:
            data = data.to(device)
            
            # Forward pass
            output, _ = model(data)
            
            # Extract ground truth labels for this batch
            ground_truth = data.y.cpu().numpy().flatten()  # Flatten if needed (for multi-dimensional labels)
            
            # Get predictions (assuming output is a continuous value for each sample)
            predictions = output.cpu().numpy().flatten()  # Flatten to match label shape
            
            y_true.extend(ground_truth)
            y_pred.extend(predictions)
    
    # Convert lists to numpy arrays
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    # Ensure predictions and ground truth have the same number of samples
    assert len(y_true) == len(y_pred), f"Mismatch in number of samples: {len(y_true)} vs {len(y_pred)}"
    
    # Compute AUROC (Area Under the Receiver Operating Characteristic Curve)
    auroc = roc_auc_score(y_true, y_pred)
    
    # Compute AUPR (Area Under the Precision-Recall Curve)
    aupr = average_precision_score(y_true, y_pred)
    
    # Compute MCC (Matthews Correlation Coefficient)
    # Threshold predictions at 0.5 to convert to binary (if binary classification)
    mcc = matthews_corrcoef(y_true, (y_pred > 0.5).astype(int))  # Apply threshold for classification
    
    return auroc, aupr, mcc

# Example usage: Calculate metrics for validation data
auroc, aupr, mcc = calculate_metrics(val_loader, model, device)

print(f"AUROC: {auroc:.4f}")
print(f"AUPR: {aupr:.4f}")
print(f"MCC: {mcc:.4f}")
