# %%
import pandas as pd
import numpy as np
import torch 
from sklearn.model_selection import train_test_split  # For splitting the dataset
from torch_geometric.data import Data  # PyTorch Geometric for graph-based data handling
from torch_geometric.data import DataLoader
from torch_geometric.nn import GCNConv, GATConv, global_mean_pool, GraphConv
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score, matthews_corrcoef

# %%
# Load the square MI matrix from a TSV file
input_file = "DREAM4_MI_1.tsv"  # Replace with your file path
mi_matrix = pd.read_csv(input_file, sep="\t", index_col=0)

# Drop the row and column labeled 'Time'
if 'Time' in mi_matrix.index:
    mi_matrix = mi_matrix.drop(index='Time')
if 'Time' in mi_matrix.columns:
    mi_matrix = mi_matrix.drop(columns='Time')

# Reset index and name the index column explicitly
mi_matrix = mi_matrix.reset_index()
mi_matrix.rename(columns={"index": "Gene1"}, inplace=True)

# Convert the square matrix into a long format
mi_long = mi_matrix.melt(id_vars="Gene1", 
                         var_name="Gene2", 
                         value_name="Mutual_Information")

# Save the result to a CSV file
output_file = "DREAM4_MI_1_3col.csv"  # Replace with your desired output path
mi_long.to_csv(output_file, sep=",", index=False)

print(f"Converted matrix saved to {output_file}")
# Out:
# Converted matrix saved to DREAM4_MI_1_3col.csv

# %%
# Read the original tsv file containing the gene connections
df = pd.read_csv('DREAM4_GoldStandard_InSilico_Size100_1.tsv', sep='\t', header=None)

# Create a list of all genes from G1 to G4511
genes = [f'G{i}' for i in range(1, 101)]  # G1 to G4511

# Create an empty square matrix of size 4511x4511 (genes x genes)
matrix = np.zeros((100, 100), dtype=int)

# Map gene names to indices for the matrix
gene_to_index = {gene: idx for idx, gene in enumerate(genes)}

# Fill the matrix with binary values based on the input data
for index, row in df.iterrows():
    gene1 = row[0]  # Gene 1
    gene2 = row[1]  # Gene 2

    # Get the corresponding indices in the matrix
    idx1 = gene_to_index.get(gene1)
    idx2 = gene_to_index.get(gene2)

    # Set the corresponding positions in the matrix to 1 for undirected edge
    if idx1 is not None and idx2 is not None:
        matrix[idx1, idx2] = 1
        matrix[idx2, idx1] = 1  # Since the connections are bidirectional

# Convert the matrix to a DataFrame for easier viewing
matrix_df = pd.DataFrame(matrix, columns=genes, index=genes)

# Save the binary matrix to a CSV file with proper headers (genes as row/column names)
matrix_df.to_csv('interaction_DREAM4_1.csv')

print("Matrix transformation complete. Saved to 'interaction_DREAM4_1.csv'.")
# Out:
# Matrix transformation complete. Saved to 'interaction_DREAM4_1.csv'.

# %%
# Load gene expression matrix (genes as columns, samples as rows)
expression_df = pd.read_csv("insilico_size100_1_timeseries.tsv", sep="\t", header=0)
gene_ids = expression_df.columns.tolist()  # Get gene IDs from column names

# Convert expression matrix to node features tensor
node_features = torch.tensor(expression_df.values.T, dtype=torch.float)  # Don't move to device yet
print(f"Node features shape: {node_features.shape}")  # Check shape
node_features = node_features.to(device)  # Now move to device

# Load mutual information data (edges) with columns: 'Gene1', 'Gene2', 'MI'
mi_df = pd.read_csv("DREAM4_MI_1_3col.csv")
mi_threshold = 0  # Set an MI threshold to filter strong interactions
mi_df = mi_df[mi_df['Mutual_Information'] > mi_threshold]

# Convert gene names to indices based on gene_ids list for compatibility with PyTorch Geometric
gene_to_idx = {gene: idx for idx, gene in enumerate(gene_ids)}

# Filter only valid gene pairs based on gene expression matrix columns
mi_df = mi_df[mi_df['Gene1'].isin(gene_to_idx) & mi_df['Gene2'].isin(gene_to_idx)]
mi_df['Gene1_idx'] = mi_df['Gene1'].map(gene_to_idx)
mi_df['Gene2_idx'] = mi_df['Gene2'].map(gene_to_idx)

# Convert to edge index tensor and edge weight tensor
edge_index = torch.tensor(mi_df[['Gene1_idx', 'Gene2_idx']].values.T, dtype=torch.long)  # Don't move to device yet
edge_index = edge_index.to(device)  # Now move to device
edge_weight = torch.tensor(mi_df['Mutual_Information'].values, dtype=torch.float).to(device)  # Move to device
print(f"Edge index shape: {edge_index.shape}")  # Check shape

# Load the ground truth interaction matrix (square matrix of 1s and 0s)
interaction_matrix = pd.read_csv("interaction_DREAM4_1.csv", header=0)
interaction_matrix = interaction_matrix.values  # Convert to numpy array

# Ensure the interaction matrix size is consistent
max_gene_idx = interaction_matrix.shape[0]  # This should be 100 based on your error

# Create ground truth labels for all gene pairs
interaction_pairs = []
ground_truth_labels = []

for i in range(interaction_matrix.shape[0]):
    for j in range(i + 1, interaction_matrix.shape[1]):  # Only consider the upper triangle to avoid duplicates
        interaction_pairs.append([i, j])
        ground_truth_labels.append(interaction_matrix[i, j])  # 1 if interaction, 0 if no interaction

# Convert the ground truth labels to a tensor
ground_truth_labels = torch.tensor(ground_truth_labels, dtype=torch.float).to(device)

# Split data into train, validation, and test sets
# First, split the edge indices and edge weights
edge_index_train, edge_index_temp, edge_weight_train, edge_weight_temp = train_test_split(
    edge_index.T.cpu().numpy(), edge_weight.cpu().numpy(), test_size=0.2, random_state=42
)
edge_index_val, edge_index_test, edge_weight_val, edge_weight_test = train_test_split(
    edge_index_temp, edge_weight_temp, test_size=0.5, random_state=42
)

# Convert back to tensors for PyTorch Geometric (on device)
edge_index_train = torch.tensor(edge_index_train.T, dtype=torch.long).to(device)
edge_weight_train = torch.tensor(edge_weight_train, dtype=torch.float).to(device)
edge_index_val = torch.tensor(edge_index_val.T, dtype=torch.long).to(device)
edge_weight_val = torch.tensor(edge_weight_val, dtype=torch.float).to(device)
edge_index_test = torch.tensor(edge_index_test.T, dtype=torch.long).to(device)
edge_weight_test = torch.tensor(edge_weight_test, dtype=torch.float).to(device)

# Sanity check for edge splits
print(f"Training edge indices: {edge_index_train.shape}")
print(f"Validation edge indices: {edge_index_val.shape}")
print(f"Test edge indices: {edge_index_test.shape}")

# Now we need to ensure that the ground truth labels match the edges for each set
# Extract corresponding ground truth labels for the splits
train_labels = []
for edge in edge_index_train.T:
    i, j = edge
    # Ensure that i and j are within bounds before accessing the interaction matrix
    if i < max_gene_idx and j < max_gene_idx:
        train_labels.append(interaction_matrix[i, j])  # Append the corresponding label

val_labels = []
for edge in edge_index_val.T:
    i, j = edge
    # Ensure that i and j are within bounds before accessing the interaction matrix
    if i < max_gene_idx and j < max_gene_idx:
        val_labels.append(interaction_matrix[i, j])  # Append the corresponding label

test_labels = []
for edge in edge_index_test.T:
    i, j = edge
    # Ensure that i and j are within bounds before accessing the interaction matrix
    if i < max_gene_idx and j < max_gene_idx:
        test_labels.append(interaction_matrix[i, j])  # Append the corresponding label

# Convert lists to tensors
train_labels = torch.tensor(train_labels, dtype=torch.float).to(device)
val_labels = torch.tensor(val_labels, dtype=torch.float).to(device)
test_labels = torch.tensor(test_labels, dtype=torch.float).to(device)

# Verify that the splits and labels match correctly
print(f"Training labels shape: {train_labels.shape}")
print(f"Validation labels shape: {val_labels.shape}")
print(f"Test labels shape: {test_labels.shape}")

# Prepare PyTorch Geometric Data object for each split
train_data = Data(x=node_features, edge_index=edge_index_train, edge_attr=edge_weight_train, y=train_labels)
val_data = Data(x=node_features, edge_index=edge_index_val, edge_attr=edge_weight_val, y=val_labels)
test_data = Data(x=node_features, edge_index=edge_index_test, edge_attr=edge_weight_test, y=test_labels)

# Verify that the data is ready for training
print(f"Training data: {train_data}")
print(f"Validation data: {val_data}")
print(f"Test data: {test_data}")
# Out:
# Node features shape: torch.Size([101, 210])
# Edge index shape: torch.Size([2, 8480])
# Training edge indices: torch.Size([2, 6784])
# Validation edge indices: torch.Size([2, 1356])
# Test edge indices: torch.Size([2, 340])
# Training labels shape: torch.Size([6673])
# Validation labels shape: torch.Size([1330])
# Test labels shape: torch.Size([334])
# Training data: Data(x=[101, 210], edge_index=[2, 6784], edge_attr=[6784], y=[6673])
# Validation data: Data(x=[101, 210], edge_index=[2, 1356], edge_attr=[1356], y=[1330])
# Test data: Data(x=[101, 210], edge_index=[2, 340], edge_attr=[340], y=[334])

# %%
from torch_geometric.data import DataLoader
# Prepare the DataLoader for PyTorch Geometric Data objects (for train, validation, test)
train_loader = DataLoader([train_data], batch_size=1, shuffle=True)
val_loader = DataLoader([val_data], batch_size=1, shuffle=False)
test_loader = DataLoader([test_data], batch_size=1, shuffle=False)
# Out:
# C:\Users\ridhi\AppData\Roaming\Python\Python312\site-packages\torch_geometric\deprecation.py:26: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %%
class EnhancedGraphAutoencoder(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super(EnhancedGraphAutoencoder, self).__init__()

        # Encoder: Combination of GCN and GAT layers with skip connections
        self.encoder_gcn1 = GCNConv(input_dim, hidden_dim * 2, add_self_loops=True, normalize=True)
        self.encoder_gat = GATConv(hidden_dim * 2, hidden_dim, heads=4, concat=False, dropout=0.3)
        self.encoder_gat2 = GATConv(hidden_dim, hidden_dim, heads=4, concat=False, dropout=0.3)

        # Latent space: A non-linear transformation of the combined embeddings
        self.latent_transform = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim * 2),
            nn.ReLU(),
            nn.Linear(hidden_dim * 2, hidden_dim)
        )

        # Decoder: Multi-layer perceptron with ReLU activations and dropout
        self.decoder = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim * 2),
            nn.ReLU(),
            nn.Dropout(0.5),  # Apply dropout
            nn.Linear(hidden_dim * 2, input_dim)
        )

        # Residual connection (identity mapping)
        self.residual = nn.Linear(input_dim, input_dim)

        # Regularization (Laplacian smoothing penalty)
        self.laplacian_penalty = 1e-3

    def forward(self, data):
        x, edge_index = data.x, data.edge_index

        # Propagation and transformation in the encoder
        x_gcn = self.encoder_gcn1(x, edge_index)
        x_gcn = torch.relu(x_gcn)
        x_gat = self.encoder_gat(x_gcn, edge_index)
        x_gat2 = self.encoder_gat2(x_gat, edge_index)

        # Latent space transformation
        latent = self.latent_transform(x_gat2)

        # Decoding and residual mapping
        decoded = self.decoder(latent)
        decoded_residual = self.residual(data.x)

        return decoded + decoded_residual, latent  # Return decoded matrix and latent embeddings

    def compute_laplacian_loss(self, x, edge_index):
        # Compute smoothness penalty using Laplacian
        row, col = edge_index
        diff = x[row] - x[col]
        laplacian_loss = self.laplacian_penalty * torch.sum(torch.norm(diff, dim=1) ** 2)
        return laplacian_loss

# Initialize the model, optimizer, and loss function
input_dim = node_features.shape[1]  # Number of input features (genes)
hidden_dim = 256  # Latent space dimension

model = EnhancedGraphAutoencoder(input_dim=input_dim, hidden_dim=hidden_dim).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
criterion = nn.MSELoss()

# Training loop with Laplacian loss and advanced regularization
def train_autoencoder(train_loader, val_loader, model, optimizer, criterion, num_epochs=200):
    train_losses = []
    val_losses = []
    
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        for data in train_loader:
            data = data.to(device)
            optimizer.zero_grad()
            
            # Forward pass
            output, embeddings = model(data)
            loss = criterion(output, data.x)  # Reconstruction loss
            
            # Add Laplacian regularization
            laplacian_loss = model.compute_laplacian_loss(embeddings, data.edge_index)
            total_loss = loss + laplacian_loss
            
            total_loss.backward()
            optimizer.step()
            running_loss += total_loss.item()

        # Log training loss
        train_losses.append(running_loss / len(train_loader))
        
        # Validation loss
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for data in val_loader:
                data = data.to(device)
                output, _ = model(data)
                loss = criterion(output, data.x)
                val_loss += loss.item()
        val_losses.append(val_loss / len(val_loader))
        
        print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_losses[-1]:.4f}, Val Loss: {val_losses[-1]:.4f}')
    
    return train_losses, val_losses

# Train the enhanced model
train_losses, val_losses = train_autoencoder(train_loader, val_loader, model, optimizer, criterion)

# Plot Training and Validation Loss
plt.figure()
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss')
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/200, Train Loss: 4221.4155, Val Loss: 3162.6311
# Epoch 2/200, Train Loss: 3153.8396, Val Loss: 2214.3340
# Epoch 3/200, Train Loss: 2158.9578, Val Loss: 1286.3807
# Epoch 4/200, Train Loss: 1577.4968, Val Loss: 598.1700
# Epoch 5/200, Train Loss: 747.6982, Val Loss: 1272.1654
# Epoch 6/200, Train Loss: 4544.0059, Val Loss: 451.7464
# Epoch 7/200, Train Loss: 1395.1748, Val Loss: 239.1893
# Epoch 8/200, Train Loss: 682.6439, Val Loss: 317.9504
# Epoch 9/200, Train Loss: 240.1237, Val Loss: 377.2829
# Epoch 10/200, Train Loss: 444.3779, Val Loss: 374.0679
# Epoch 11/200, Train Loss: 323.6445, Val Loss: 330.7245
# Epoch 12/200, Train Loss: 340.1300, Val Loss: 272.4533
# Epoch 13/200, Train Loss: 267.5116, Val Loss: 212.9301
# Epoch 14/200, Train Loss: 216.0284, Val Loss: 160.3313
# Epoch 15/200, Train Loss: 157.8510, Val Loss: 119.5385
# Epoch 16/200, Train Loss: 132.4551, Val Loss: 94.1915
# Epoch 17/200, Train Loss: 97.5741, Val Loss: 85.1953
# Epoch 18/200, Train Loss: 99.8112, Val Loss: 82.8565
# Epoch 19/200, Train Loss: 76.6314, Val Loss: 83.2117
# Epoch 20/200, Train Loss: 77.4701, Val Loss: 81.5947
# Epoch 21/200, Train Loss: 58.6367, Val Loss: 81.3923
# Epoch 22/200, Train Loss: 92.1185, Val Loss: 73.7910
# Epoch 23/200, Train Loss: 108.6572, Val Loss: 60.5353
# Epoch 24/200, Train Loss: 63.1588, Val Loss: 51.3900
# Epoch 25/200, Train Loss: 55.4589, Val Loss: 46.0716
# Epoch 26/200, Train Loss: 48.1323, Val Loss: 42.4031
# Epoch 27/200, Train Loss: 44.0645, Val Loss: 38.8197
# Epoch 28/200, Train Loss: 40.8982, Val Loss: 35.0096
# Epoch 29/200, Train Loss: 34.2799, Val Loss: 31.3600
# Epoch 30/200, Train Loss: 33.2702, Val Loss: 27.6816
# Epoch 31/200, Train Loss: 26.3223, Val Loss: 24.4565
# Epoch 32/200, Train Loss: 25.2967, Val Loss: 21.3855
# Epoch 33/200, Train Loss: 21.4560, Val Loss: 18.5701
# Epoch 34/200, Train Loss: 18.3068, Val Loss: 16.0785
# Epoch 35/200, Train Loss: 16.1623, Val Loss: 13.9956
# Epoch 36/200, Train Loss: 14.2959, Val Loss: 12.2317
# Epoch 37/200, Train Loss: 13.2516, Val Loss: 10.6893
# Epoch 38/200, Train Loss: 10.6386, Val Loss: 9.4636
# Epoch 39/200, Train Loss: 9.4213, Val Loss: 8.4936
# Epoch 40/200, Train Loss: 8.2321, Val Loss: 7.6916
# Epoch 41/200, Train Loss: 7.6651, Val Loss: 6.9579
# Epoch 42/200, Train Loss: 8.4151, Val Loss: 6.0524
# Epoch 43/200, Train Loss: 6.2340, Val Loss: 5.2139
# Epoch 44/200, Train Loss: 5.5963, Val Loss: 4.5061
# Epoch 45/200, Train Loss: 4.7778, Val Loss: 3.9388
# Epoch 46/200, Train Loss: 4.0154, Val Loss: 3.4788
# Epoch 47/200, Train Loss: 3.1952, Val Loss: 3.0742
# Epoch 48/200, Train Loss: 2.9519, Val Loss: 2.6974
# Epoch 49/200, Train Loss: 3.1918, Val Loss: 2.3580
# Epoch 50/200, Train Loss: 2.5793, Val Loss: 2.0665
# Epoch 51/200, Train Loss: 2.3540, Val Loss: 1.8746
# Epoch 52/200, Train Loss: 2.3318, Val Loss: 1.7693
# Epoch 53/200, Train Loss: 1.8963, Val Loss: 1.6918
# Epoch 54/200, Train Loss: 1.7369, Val Loss: 1.6624
# Epoch 55/200, Train Loss: 2.1827, Val Loss: 1.4450
# Epoch 56/200, Train Loss: 1.6249, Val Loss: 1.2087
# Epoch 57/200, Train Loss: 1.5491, Val Loss: 1.0318
# Epoch 58/200, Train Loss: 1.3365, Val Loss: 1.0645
# Epoch 59/200, Train Loss: 4.6995, Val Loss: 1.0703
# Epoch 60/200, Train Loss: 1.2302, Val Loss: 1.3384
# Epoch 61/200, Train Loss: 1.6061, Val Loss: 1.2700
# Epoch 62/200, Train Loss: 1.4555, Val Loss: 1.1697
# Epoch 63/200, Train Loss: 1.2720, Val Loss: 1.1121
# Epoch 64/200, Train Loss: 1.4463, Val Loss: 1.0457
# Epoch 65/200, Train Loss: 0.8561, Val Loss: 1.0009
# Epoch 66/200, Train Loss: 0.7896, Val Loss: 0.9689
# Epoch 67/200, Train Loss: 0.7189, Val Loss: 0.9063
# Epoch 68/200, Train Loss: 1.3690, Val Loss: 0.7396
# Epoch 69/200, Train Loss: 4.8103, Val Loss: 0.4462
# Epoch 70/200, Train Loss: 1.1109, Val Loss: 0.4844
# Epoch 71/200, Train Loss: 0.5340, Val Loss: 0.6800
# Epoch 72/200, Train Loss: 0.7377, Val Loss: 0.8497
# Epoch 73/200, Train Loss: 0.7288, Val Loss: 0.9201
# Epoch 74/200, Train Loss: 0.9053, Val Loss: 0.9020
# Epoch 75/200, Train Loss: 0.8719, Val Loss: 0.8281
# Epoch 76/200, Train Loss: 0.7572, Val Loss: 0.7028
# Epoch 77/200, Train Loss: 0.6570, Val Loss: 0.5557
# Epoch 78/200, Train Loss: 0.5994, Val Loss: 0.4259
# Epoch 79/200, Train Loss: 0.4444, Val Loss: 0.3374
# Epoch 80/200, Train Loss: 0.4062, Val Loss: 0.2871
# Epoch 81/200, Train Loss: 0.3421, Val Loss: 0.2611
# Epoch 82/200, Train Loss: 0.2747, Val Loss: 0.2555
# Epoch 83/200, Train Loss: 0.4418, Val Loss: 0.2402
# Epoch 84/200, Train Loss: 0.2903, Val Loss: 0.2367
# Epoch 85/200, Train Loss: 0.2261, Val Loss: 0.2409
# Epoch 86/200, Train Loss: 0.2566, Val Loss: 0.2364
# Epoch 87/200, Train Loss: 0.2061, Val Loss: 0.2294
# Epoch 88/200, Train Loss: 0.3920, Val Loss: 0.2206
# Epoch 89/200, Train Loss: 0.2382, Val Loss: 0.2138
# Epoch 90/200, Train Loss: 0.2801, Val Loss: 0.1862
# Epoch 91/200, Train Loss: 0.3691, Val Loss: 0.1478
# Epoch 92/200, Train Loss: 0.1646, Val Loss: 0.1236
# Epoch 93/200, Train Loss: 0.1463, Val Loss: 0.1165
# Epoch 94/200, Train Loss: 0.1423, Val Loss: 0.1163
# Epoch 95/200, Train Loss: 0.1779, Val Loss: 0.1074
# Epoch 96/200, Train Loss: 0.1339, Val Loss: 0.0983
# Epoch 97/200, Train Loss: 0.1296, Val Loss: 0.0972
# Epoch 98/200, Train Loss: 0.1110, Val Loss: 0.1086
# Epoch 99/200, Train Loss: 0.1204, Val Loss: 0.1123
# Epoch 100/200, Train Loss: 0.1023, Val Loss: 0.1049
# Epoch 101/200, Train Loss: 0.1029, Val Loss: 0.0953
# Epoch 102/200, Train Loss: 0.0979, Val Loss: 0.0879
# Epoch 103/200, Train Loss: 0.0812, Val Loss: 0.0852
# Epoch 104/200, Train Loss: 0.0863, Val Loss: 0.0791
# Epoch 105/200, Train Loss: 0.0901, Val Loss: 0.0696
# Epoch 106/200, Train Loss: 0.0804, Val Loss: 0.0609
# Epoch 107/200, Train Loss: 0.0708, Val Loss: 0.0560
# Epoch 108/200, Train Loss: 0.0781, Val Loss: 0.0539
# Epoch 109/200, Train Loss: 0.0638, Val Loss: 0.0521
# Epoch 110/200, Train Loss: 0.0635, Val Loss: 0.0502
# Epoch 111/200, Train Loss: 0.0615, Val Loss: 0.0488
# Epoch 112/200, Train Loss: 0.0632, Val Loss: 0.0483
# Epoch 113/200, Train Loss: 0.0689, Val Loss: 0.0490
# Epoch 114/200, Train Loss: 0.0546, Val Loss: 0.0481
# Epoch 115/200, Train Loss: 0.0589, Val Loss: 0.0452
# Epoch 116/200, Train Loss: 0.0477, Val Loss: 0.0418
# Epoch 117/200, Train Loss: 0.0740, Val Loss: 0.0393
# Epoch 118/200, Train Loss: 0.0446, Val Loss: 0.0375
# Epoch 119/200, Train Loss: 0.0427, Val Loss: 0.0360
# Epoch 120/200, Train Loss: 0.0383, Val Loss: 0.0352
# Epoch 121/200, Train Loss: 0.0383, Val Loss: 0.0349
# Epoch 122/200, Train Loss: 0.0377, Val Loss: 0.0351
# Epoch 123/200, Train Loss: 0.0382, Val Loss: 0.0348
# Epoch 124/200, Train Loss: 0.0393, Val Loss: 0.0337
# Epoch 125/200, Train Loss: 0.0445, Val Loss: 0.0321
# Epoch 126/200, Train Loss: 0.0410, Val Loss: 0.0309
# Epoch 127/200, Train Loss: 0.0383, Val Loss: 0.0303
# Epoch 128/200, Train Loss: 0.0360, Val Loss: 0.0302
# Epoch 129/200, Train Loss: 0.0322, Val Loss: 0.0303
# Epoch 130/200, Train Loss: 0.0333, Val Loss: 0.0301
# Epoch 131/200, Train Loss: 0.0325, Val Loss: 0.0298
# Epoch 132/200, Train Loss: 0.0348, Val Loss: 0.0296
# Epoch 133/200, Train Loss: 0.0311, Val Loss: 0.0294
# Epoch 134/200, Train Loss: 0.0312, Val Loss: 0.0290
# Epoch 135/200, Train Loss: 0.0333, Val Loss: 0.0288
# Epoch 136/200, Train Loss: 0.0303, Val Loss: 0.0287
# Epoch 137/200, Train Loss: 0.0300, Val Loss: 0.0286
# Epoch 138/200, Train Loss: 0.0315, Val Loss: 0.0283
# Epoch 139/200, Train Loss: 0.0296, Val Loss: 0.0280
# Epoch 140/200, Train Loss: 0.0297, Val Loss: 0.0275
# Epoch 141/200, Train Loss: 0.0329, Val Loss: 0.0272
# Epoch 142/200, Train Loss: 0.0288, Val Loss: 0.0271
# Epoch 143/200, Train Loss: 0.0314, Val Loss: 0.0268
# Epoch 144/200, Train Loss: 0.0296, Val Loss: 0.0268
# Epoch 145/200, Train Loss: 0.0294, Val Loss: 0.0268
# Epoch 146/200, Train Loss: 0.0305, Val Loss: 0.0266
# Epoch 147/200, Train Loss: 0.0306, Val Loss: 0.0263
# Epoch 148/200, Train Loss: 0.0312, Val Loss: 0.0263
# Epoch 149/200, Train Loss: 0.0274, Val Loss: 0.0265
# Epoch 150/200, Train Loss: 0.0285, Val Loss: 0.0267
# Epoch 151/200, Train Loss: 0.0298, Val Loss: 0.0268
# Epoch 152/200, Train Loss: 0.0301, Val Loss: 0.0265
# Epoch 153/200, Train Loss: 0.0283, Val Loss: 0.0260
# Epoch 154/200, Train Loss: 0.0273, Val Loss: 0.0257
# Epoch 155/200, Train Loss: 0.0274, Val Loss: 0.0256
# Epoch 156/200, Train Loss: 0.0271, Val Loss: 0.0254
# Epoch 157/200, Train Loss: 0.0270, Val Loss: 0.0250
# Epoch 158/200, Train Loss: 0.0281, Val Loss: 0.0248
# Epoch 159/200, Train Loss: 0.0275, Val Loss: 0.0248
# Epoch 160/200, Train Loss: 0.0277, Val Loss: 0.0249
# Epoch 161/200, Train Loss: 0.0270, Val Loss: 0.0249
# Epoch 162/200, Train Loss: 0.0266, Val Loss: 0.0248
# Epoch 163/200, Train Loss: 0.0268, Val Loss: 0.0247
# Epoch 164/200, Train Loss: 0.0273, Val Loss: 0.0246
# Epoch 165/200, Train Loss: 0.0271, Val Loss: 0.0245
# Epoch 166/200, Train Loss: 0.0260, Val Loss: 0.0245
# Epoch 167/200, Train Loss: 0.0256, Val Loss: 0.0246
# Epoch 168/200, Train Loss: 0.0262, Val Loss: 0.0245
# Epoch 169/200, Train Loss: 0.0272, Val Loss: 0.0244
# Epoch 170/200, Train Loss: 0.0268, Val Loss: 0.0243
# Epoch 171/200, Train Loss: 0.0264, Val Loss: 0.0242
# Epoch 172/200, Train Loss: 0.0258, Val Loss: 0.0241
# Epoch 173/200, Train Loss: 0.0260, Val Loss: 0.0240
# Epoch 174/200, Train Loss: 0.0259, Val Loss: 0.0240
# Epoch 175/200, Train Loss: 0.0254, Val Loss: 0.0241
# Epoch 176/200, Train Loss: 0.0271, Val Loss: 0.0240
# Epoch 177/200, Train Loss: 0.0264, Val Loss: 0.0239
# Epoch 178/200, Train Loss: 0.0254, Val Loss: 0.0239
# Epoch 179/200, Train Loss: 0.0254, Val Loss: 0.0240
# Epoch 180/200, Train Loss: 0.0253, Val Loss: 0.0239
# Epoch 181/200, Train Loss: 0.0254, Val Loss: 0.0238
# Epoch 182/200, Train Loss: 0.0261, Val Loss: 0.0237
# Epoch 183/200, Train Loss: 0.0251, Val Loss: 0.0237
# Epoch 184/200, Train Loss: 0.0251, Val Loss: 0.0236
# Epoch 185/200, Train Loss: 0.0263, Val Loss: 0.0237
# Epoch 186/200, Train Loss: 0.0258, Val Loss: 0.0238
# Epoch 187/200, Train Loss: 0.0257, Val Loss: 0.0239
# Epoch 188/200, Train Loss: 0.0258, Val Loss: 0.0240
# Epoch 189/200, Train Loss: 0.0267, Val Loss: 0.0240
# Epoch 190/200, Train Loss: 0.0248, Val Loss: 0.0240
# Epoch 191/200, Train Loss: 0.0249, Val Loss: 0.0238
# Epoch 192/200, Train Loss: 0.0258, Val Loss: 0.0238
# Epoch 193/200, Train Loss: 0.0245, Val Loss: 0.0238
# Epoch 194/200, Train Loss: 0.0252, Val Loss: 0.0236
# Epoch 195/200, Train Loss: 0.0255, Val Loss: 0.0233
# Epoch 196/200, Train Loss: 0.0253, Val Loss: 0.0233
# Epoch 197/200, Train Loss: 0.0248, Val Loss: 0.0234
# Epoch 198/200, Train Loss: 0.0250, Val Loss: 0.0235
# Epoch 199/200, Train Loss: 0.0251, Val Loss: 0.0233
# Epoch 200/200, Train Loss: 0.0243, Val Loss: 0.0232

# %%
# Evaluate the model
def evaluate_model(test_loader, model):
    model.eval()
    all_labels = []
    all_preds = []
    with torch.no_grad():
        for data in test_loader:
            data = data.to(device)
            output, _ = model(data)
            all_labels.append(data.x.cpu().numpy())  # True data (gene expression)
            all_preds.append(output.cpu().numpy())   # Predicted data (reconstructed expression)

    # Flatten the lists for ROC and PR calculations
    all_labels = np.concatenate(all_labels, axis=0)
    all_preds = np.concatenate(all_preds, axis=0)

    # You may need to define your own threshold based on the problem
    all_labels_binary = (all_labels > 0.5).astype(int)  # Threshold at 0.5
    all_preds_binary = (all_preds > 0.5).astype(int)

    return all_labels_binary, all_preds_binary, all_preds

# Get predictions
y_true, y_pred_binary, y_pred_prob = evaluate_model(test_loader, model)

# Calculate ROC curve
fpr, tpr, _ = roc_curve(y_true.flatten(), y_pred_prob.flatten())
roc_auc = auc(fpr, tpr)

# Calculate PR curve
precision, recall, _ = precision_recall_curve(y_true.flatten(), y_pred_prob.flatten())
average_precision = average_precision_score(y_true.flatten(), y_pred_prob.flatten())

# Calculate MCC
mcc = matthews_corrcoef(y_true.flatten(), y_pred_binary.flatten())

# Print AUPR, AUROC, and MCC
print(f'AUROC: {roc_auc:.4f}')
print(f'AUPR: {average_precision:.4f}')
print(f'Matthews Correlation Coefficient (MCC): {mcc:.4f}')

# Plot ROC curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Plot PR curve
plt.figure()
plt.plot(recall, precision, color='b', lw=2, label=f'PR curve (AP = {average_precision:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='lower left')
plt.show()
# Out:
# AUROC: 0.8727
# AUPR: 0.7529
# Matthews Correlation Coefficient (MCC): 0.5411
